# %%
def sum(a,b):
    return a+b
    a = int(input("enter a"))
    b = int(input("enetr b"))
x = sum(5,10)
print("sum=",x)
# Out:
# sum= 15

# %%
def sum(a,b):
    return a+b
    a = int(input("enter a"))
    b = int(input("enetr b"))
x = sum(5,10)
print("sum=",x)
# Out:
# sum= 15

# %%
n = int(input("enetr the n"))
def comp_val(str):
    if (n%2== 0):
        print("even")
    else:
        print("odd")
comp_val(n)
# Out:
# enetr the n 7
# odd

# %%
n = int(input("enter the n"))
def even_odd(str):
    if (n%2==0):
        print("even")
    else:
        print("odd")
even_odd(n)
# Out:
# enter the n 2
# even

# %%
def maximum(a,b,c):
    return max(a,b,c)

x = maximum(3,5,6)
print(x)
# Out:
# 6

# %%
def maximum(a,b,c):
    if a>b and a>c:
        print("a is greater")
    elif b>a and b>c:
        print("b is greater")
    else:
        print("c is greater")
x = maximum(10,20,30)
print(x)
# Out:
# c is greater
# None
